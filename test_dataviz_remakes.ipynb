# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Jun 14 15:01:27 2019

@author: moi
"""

#Import des librairies

import requests
from pandas.io.json import json_normalize
import pandas as pd
import qgrid

#Nombre de remakes par année et par film d'origine

#Ouverture en Dataframe
URL = "/home/moi/Documents/Projet_movies/Finalised/remake-modifie-Alex-Cyprien.csv"
df = pd.read_csv(URL, sep=',')
print(df)
# Out:
#      filmid                              title    year priorfilm  \
# 0      AA13                          Pygmalion  1938.0     LuB20
# 1      AA13                          Pygmalion  1938.0      HH15
# 2     AAl20                    Betsy's Wedding  1990.0       VM9
# 3     AbF10                             Ms. 45  1981.0     MiW22
# 4     AbF27                     Body Snatchers  1994.0       PK5
# 5     ABo10                      And God Spoke  1993.0     CDM80
# 6      AC20            The Great Impersonation  1935.0     Z2110
# 7     ACy10               Les Amants de Verone  1949.0      GC15
# 8     AdL20                             Lolita  1997.0      StK6
# 9     ADv15                        Under Siege  1992.0     IMT10
# 10    ADv22                   A Perfect Murder  1998.0       H50
# 11    ADT18                       House of Wax  1953.0       C91
# 12    ADx35           To Woody Allen with Love  1983.0       WA9
# ...

# %%
# Création du qgrid
edit_df = qgrid.show_grid(df, show_toolbar=True)
edit_df

tb_stat = df.groupby(['priortitle','year'], as_index=False)['filmid'].count()

# Filtrage pour éliminer les données manquantes
tb_stat = tb_stat[tb_stat.priortitle != ""]
tb_stat = tb_stat[tb_stat.year != ""]
tb_stat = tb_stat[tb_stat.year != "0.3"]


#tb_stat_large = tb_stat.pivot(index='year', columns='priortitle', values='title')
#tb_stat_large
#import qgrid
#edit_tb = qgrid.show_grid(tb_stat_large, show_toolbar=True)
#edit_tb

#Highchart

#from highcharts import Highchart
#H = Highchart()
#for i in tb_stat_large:
#    H.add_data_set(list(tb_stat_large[i]), 'spline', i)
#H

import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np

#N = 100
#random_x = np.linspace(0, 1, N)
#random_y0 = np.random.randn(N)+5
#random_y1 = np.random.randn(N)
#random_y2 = np.random.randn(N)-5

# Create trace
trace = go.Scatter(
    x = tb_stat['year'],
    y = tb_stat['priortitle'],
    mode = 'markers',
    name = 'remakes'
)

data = [trace]
py.iplot(data, filename='scatter-mode')
# Out:
# /home/moi/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~RemiJulien/10.embed" height="525px" width="100%"></iframe>
